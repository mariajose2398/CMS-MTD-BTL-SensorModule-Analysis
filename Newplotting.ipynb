# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("BTL @ UVA Logbook - Module Measurements.csv")

# %%
data=np.genfromtxt("BTL @ UVA Logbook - Module Measurements.csv", delimiter=',', comments='#', dtype="|U5")

# %%
data
# Out:
# array([['"04 O', ' 2022', 'Bryan', 'L1+S2', '58.99', '59.01', '58.98',
#         '58.94', '58.91', 'TRUE', 'BC', ''],
#        ['"04 O', ' 2022', 'Repea', 'L1+S2', '59.00', '59.00', '58.99',
#         '58.94', '58.90', 'TRUE', '"BC"', ''],
#        ['"04 O', ' 2022', 'Repea', 'L1+S2', '58.99', '59.01', '58.98',
#         '58.94', '58.90', 'TRUE', 'BC', ''],
#        ['"04 O', ' 2022', 'Repea', 'L1+S2', '58.98', '58.98', '59.00',
#         '58.94', '58.90', 'TRUE', 'BC', ''],
#        ['"04 O', ' 2022', 'Repea', 'L1+S2', '58.99', '59.00', '58.99',
#         '58.95', '58.90', 'TRUE', 'BC', ''],
#        ['"04 O', ' 2022', 'Repea', 'L1+S2', '58.99', '58.99', '58.98',
#         '58.94', '58.90', 'TRUE', 'BC', ''],
#        ['"06 O', ' 2022', 'Maria', 'L1+S2', '58.89', '58.94', '59.00',
#         '59.01', '58.98', '', 'MJ', ''],
#        ['"20 O', ' 2022', 'Maria', 'L1+S2', '58.89', '58.93', '58.97',
#         '58.99', '58.98', '', 'MJ', ''],
# ...
