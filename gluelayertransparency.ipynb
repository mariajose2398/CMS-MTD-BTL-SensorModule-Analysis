# %%
import numpy as np
import matplotlib.pyplot as plt
l1_1=np.array([56.588,56.639,56.709,56.682,56.662])
l1_2=np.array([56.577,56.611,56.654, 56.659,56.602])
l1=(l1_1 +l1_2)/2

# use [::-1] to reverse order of measurements when necessary
s2=np.array([2.309,2.309,2.306,2.309,2.308])
m1=np.array([58.994,59.010,58.982,58.942,58.918])[::-1]
m2=np.array([59.000,59.001,58.997,58.946,58.908])[::-1]
m3=np.array([58.995,59.011,58.983,58.945,58.905])[::-1]
m4=np.array([58.985,58.988,59.000,58.948,58.903])[::-1]
m5=np.array([58.993,59.007,58.990,58.951,58.905])[::-1]
m6=np.array([58.995,58.995,58.984,58.947,58.901])[::-1]
m7=np.array([58.895,58.946,59.003,59.015,58.984])
m8=np.array([58.894,58.937, 58.978,58.993,58.982])
m9=np.array([58.896,58.928,58.980,58.995,58.971])
m10=np.array([58.898,58.942,58.976,59.005,59.000])
m11=np.array([58.900,58.939,58.986,58.997,59.000])
m12=np.array([58.900,58.941,58.979,58.996,58.992])
m13=np.array([58.989,59.007,58.974,58.941,58.904])[::-1]
m14=np.array([58.898,58.942,58.976,59.005,59.000])
X=np.array(["A", "B", "C", "D", "E"])

plt.ylim(-20, 100)

plt.plot(X, (m1-l1-s2)*1000, "C1", label ="m1(BC)")
plt.plot(X, (m2-l1-s2) *1000 , "C1", label="m2(BC)")
plt.plot(X, (m3-l1-s2) *1000, "C1", label ="m3(BC)")
plt.plot(X, (m4-l1-s2)*1000, "C1", label="m4(BC)")
plt.plot(X, (m5-l1-s2)*1000, "C1", label ="m5(BC)")
plt.plot(X, (m6-l1-s2)*1000, "C1", label ="m6(BC)")
plt.plot(X, (m7-l1-s2)*1000, "C2", label ="m7(MJ)")
plt.plot(X, (m8-l1-s2)*1000, "C2", label="m8(MJ)")
plt.plot(X, (m9-l1-s2)*1000, "C2", label="m9(MJ)")
plt.plot(X, (m10-l1-s2)*1000, "C1", label="m10(BC)")
plt.plot(X, (m11-l1-s2)*1000, "C1", label="m11(BC)")
plt.plot(X, (m12-l1-s2)*1000, "C1", label="m12(BC)")
plt.plot(X, (m13-l1-s2)*1000, "C1", label="m13(BC)")
plt.plot(X, (m14-l1-s2)*1000, "C1", label="m14(BC)")
plt.ylabel(r"Glue Layer Thickness($\mu $m)")
plt.title("Glue Layer Thickness for L1+S2")

plt.savefig("l1s2_mariaVsBryan.png", dpi=300)
plt.show()

# %%
#Measurement plot of L3 +S3 mock up module.
L3= np.array([[56.706,56.729,56.745, 56.693, 56.614],
     [56.706,56.729,56.744,56.691,56.619]])
L3_avg=np.mean(L3, axis=0)
print(L3_avg)

S3= np.array([[2.308,2.312,2.306,2.306,2.309],
              [2.310,2.310,2.307,2.308,2.308]])
S3_avg= np.mean(S3, axis=0)
print(S3_avg)

whomeasured=['M', 'M', 'M','B', 'B']
L3S3=np.array([[59.087,59.127,59.137,59.046,58.924],
               [59.085,59.127,59.134,59.026,58.915],
               [59.078,59.127,59.133,59.025,58.905],
               [59.091,59.134,59.128,59.045,58.930],
               [59.099,59.132,59.131,59.043,58.934]])

for x in range(len(L3S3)):
    if whomeasured[x] == 'M':
        plt.plot(X, (L3S3[x]-L3_avg-S3_avg)*1000, "C2", label ="MJ")
    if whomeasured[x] =='B':
        plt.plot(X, (L3S3[x]-L3_avg-S3_avg)*1000, "C1", label ="BC")
plt.ylabel(r"Glue Layer Thickness($\mu$m)")
plt.title("Glue Layer Thickness for L3+S3")
plt.legend()
plt.ylim(-20, 100)
plt.savefig("l3s3measurement.png")
plt.show()
# Out:
# [56.706  56.729  56.7445 56.692  56.6165]
# [2.309  2.311  2.3065 2.307  2.3085]

# %%
#Measurement plot of L2 +S4 mock up module.
L2= np.array([[56.380,56.519,56.535,56.509,56.466],
              [56.377,56.473,56.522,56.500,56.454],
              [56.376,56.457,56.526,56.499,56.450]])
L2_avg=np.mean(L2, axis=0)
print(L2_avg)

S4= np.array([[2.309,2.308,2.308,2.309,2.309],
              [2.306,2.308,2.306,2.307,2.307]])
S4_avg= np.mean(S4, axis=0)
print(S4_avg)
plt.ylim(-20, 100)
whomeasured=['B', 'B', 'B', 'B']
L2S4=np.array([[58.701,58.787,58.872,58.864,58.846],
               [58.701,58.782,58.863,58.862,58.850],
               [58.711,58.785,58.854,58.863,58.847],
               [58.704,58.781,58.866,58.863,58.847]])

for x in range(len(L2S4)):
    if whomeasured[x] == 'M':
        plt.plot(X, (L2S4[x]-L2_avg-S4_avg)*1000, "C2", label ="MJ")
    if whomeasured[x] =='B':
        plt.plot(X, (L2S4[x]-L2_avg-S4_avg)*1000, "C1", label ="BC")
plt.ylabel(r"Glue Layer Thickness($\mu$m)")
plt.title("Glue Layer Thickness for L2+S4")
plt.legend()
plt.savefig("l2s4measurement.png")
plt.show()
# Out:
# [56.37766667 56.483      56.52766667 56.50266667 56.45666667]
# [2.3075 2.308  2.307  2.308  2.308 ]

# %%
#Measurement plot for L6+S1
L6S1_noglue=np.array([[59.162,59.151,59.146,59.138,59.095],             
             [59.142,59.150,59.143,59.147,59.098]])
L6 =np.array([[56.838,56.849,56.829,56.816,56.782],
              [56.831,56.842,56.842,56.824,56.783],
              [56.830,56.835,56.832,56.825,56.795],
              [56.831,56.849,56.835,56.828,56.788]])
S1=np.array([[2.310,2.310,2.309,2.308,2.308],
             [2.305,2.306,2.307,2.306,2.309]])

X=np.array(["A", "B", "C", "D", "E"])
L6S1 = np.array([[59.146,59.169,59.206,59.162,59.125],
                 [59.147,59.154,59.159,59.155,59.134],
                 [59.155,59.165,59.171,59.160,59.152],
                 [59.144,59.163,59.167,59.159,59.139]])
whomeasured=['M', 'M','B', 'B']
for x in range(len(L6S1)):
    if whomeasured[x] == 'M':
        plt.plot(X, (L6S1[x]-np.mean(L6, axis=0)-np.mean(S1, axis=0))*1000, "C2", label ="MJ")
    if whomeasured[x] =='B':
        plt.plot(X, (L6S1[x]-np.mean(L6, axis=0)-np.mean(S1, axis=0))*1000, "C1", label ="BC")
    #plt.plot(X, (L6S1[x]-np.mean(L6S1_noglue, axis=0))*1000, "C3", label="no glue")
plt.ylabel(r"Glue Layer Thickness($\mu$m)")
plt.title("Glue Layer Thickness for L6+S1")
plt.ylim(-20, 100)
plt.legend()
plt.savefig("l6s1measurement.png")
plt.show()

# %%
#L4S5 glue layer thickness
L4S5=np.array([[59.130,59.168,59.164,59.147,59.093],
               [59.128,59.159,59.158,59.143,59.085],
               [59.130,59.160,59.161,59.143,59.090]])
L4=np.array([[56.808,56.830,56.825,56.796,56.747],
             [56.810,56.820,56.827,56.795,56.749]])
S5=np.array([[2.310,2.309,2.311,2.309,2.310],
             [2.307,2.308,2.307,2.309,2.308]])
whomeasured=['B', 'B', 'B']
for x in range(len(L4S5)):
    if whomeasured[x] == 'M':
        plt.plot(X, (L4S5[x]-np.mean(L4, axis=0)-np.mean(S5, axis=0))*1000, "C2", label ="MJ")
    if whomeasured[x] =='B':
        plt.plot(X, (L4S5[x]-np.mean(L4, axis=0)-np.mean(S5, axis=0))*1000, "C1", label ="BC")
        
plt.ylabel(r"Glue Layer Thickness($\mu$m)")
plt.title("Glue Layer Thickness for L4+S5")
plt.ylim(-20, 100)
plt.legend()
plt.savefig("l4s5measurement.png")
plt.show()
