# %%
import numpy as np
import matplotlib.pyplot as plt
l1_1=np.array([56.588,56.639,56.709,56.682,56.662])
l1_2=np.array([56.577,56.611,56.654, 56.659,56.602])
l1=(l1_1 +l1_2)/2

s2=np.array([2.309,2.309,2.306,2.309,2.308])
m1=np.array([58.994,59.010,58.982,58.942,58.918])
m2=np.array([59.000,59.001,58.997,58.946,58.908])
m3=np.array([58.995,59.011,58.983,58.945,58.905])
m4=np.array([58.985,58.988,59.000,58.948,58.903])
m5=np.array([58.993,59.007,58.990,58.951,58.905])
m6=np.array([58.995,58.995,58.984,58.947,58.901])
m7=np.array([58.895,58.946,59.003,59.015,58.984])
m8=np.array([58.894,58.937, 58.978,58.993,58.982])
m9=np.array([58.896,58.928,58.980,58.995,58.971])
X=np.array(["A", "B", "C", "D", "E"])

plt.plot(X, m1-l1-s2, label ="m1(BC)")
plt.plot(X, m2-l1-s2, label="m2(BC)")
plt.plot(X, m3-l1-s2, label ="m3(BC)")
plt.plot(X, m4-l1-s2, label="m4(BC)")
plt.plot(X, m5-l1-s2, label ="m5(BC)")
plt.plot(X, m6-l1-s2, label ="m6(BC)")
plt.plot(X, m7-l1-s2, label ="m7(MJ)")
plt.plot(X, m8-l1-s2, label="m8(MJ)")
plt.plot(X, m9-l1-s2, label="m9(MJ)")
plt.ylabel("Glue Layer Thickness(mm)")
plt.title("Glue Layer Thickness for L1+S2")
plt.legend()
plt.show()
